# %%
import pandas as pd
df_skill_list = pd.DataFrame({
  'job_short_title': ['Data Analyst', 'Data Scientist', 'Data Engineer'],
  'skill': [['SQL', 'Excel', 'Python'], ['Python', 'Machine Learning', 'R'], ['Hadoop', 'Python', 'Spark', 'ETL', 'R']]})

# %%
df_skill_list
# Out:
#   job_short_title                            skill
# 0    Data Analyst             [SQL, Excel, Python]
# 1  Data Scientist    [Python, Machine Learning, R]
# 2   Data Engineer  [Hadoop, Python, Spark, ETL, R]

# %%
df_skill_list.explode('skill').value_counts('skill').plot(kind='bar')
# Out:
# <Axes: xlabel='skill'>

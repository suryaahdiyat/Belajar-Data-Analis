# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
import pandas as pd
from datasets import load_dataset

# loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# convert to datetime
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
# df.head()
# df.tail(10)
# df['job_title_short'].head()
df[['job_title_short', 'job_location']].head(100)
# Out:
#          job_title_short                  job_location
# 0   Senior Data Engineer                 Watertown, CT
# 1           Data Analyst  Guadalajara, Jalisco, Mexico
# 2          Data Engineer               Berlin, Germany
# 3          Data Engineer               San Antonio, TX
# 4          Data Engineer                Washington, DC
# ..                   ...                           ...
# 95         Data Engineer    Mumbai, Maharashtra, India
# 96         Data Engineer                  Torrance, CA
# 97          Data Analyst                United Kingdom
# 98  Senior Data Engineer           Toronto, ON, Canada
# 99         Data Engineer                     Miami, FL
#
# [100 rows x 2 columns]

# %%
# df.iloc[95:99]
# df.iloc[95:99, 0:3:2]
df[['job_title_short', 'job_location']].iloc[95:99]
# Out:
#          job_title_short                job_location
# 95         Data Engineer  Mumbai, Maharashtra, India
# 96         Data Engineer                Torrance, CA
# 97          Data Analyst              United Kingdom
# 98  Senior Data Engineer         Toronto, ON, Canada

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna()) & (df.job_work_from_home)]
# Out:
#        job_title_short                              job_title job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst     Anywhere
# 4709      Data Analyst                           Data Analyst     Anywhere
# 5478      Data Analyst     Investment Operations Data Analyst     Anywhere
# 7081      Data Analyst                           Data Analyst     Anywhere
# 8839      Data Analyst         Digital Marketing Data Analyst     Anywhere
# ...                ...                                    ...          ...
# 774079    Data Analyst                           Data Analyst     Anywhere
# 774501    Data Analyst                Data Analyst / Engineer     Anywhere
# 774548    Data Analyst    GTM Revenue Operations Data Analyst     Anywhere
# 774558    Data Analyst             Data Analyst Lead - Remote     Anywhere
# 775088    Data Analyst                           Data Analyst     Anywhere
#
# ...

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
# convert to datetime
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df[50:60]
# Out:
#               job_title_short                                 job_title  \
# 50  Machine Learning Engineer  Sr ML Engineer - Research & NLP (Remote)
# 51       Senior Data Engineer                      Senior Data Engineer
# 52             Data Scientist     Data Scientist SME or Program Manager
# 53              Data Engineer                             Data Engineer
# 54              Data Engineer               Data and Analytics Engineer
# 55             Data Scientist                            Data Scientist
# 56      Senior Data Scientist           Principal Statistical Scientist
# 57              Data Engineer                             Data Engineer
# 58      Senior Data Scientist                     Senior Data Scientist
# 59              Data Engineer      Data Engineer with Dremio Experience
#
#                                   job_location                  job_via  \
# 50                         Toronto, ON, Canada  via Careers At BenchSci
# ...

# %%
df.sort_values(by='job_posted_date', inplace=True)

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
# droping a column
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
# deleting nan value in data
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
import pandas as pd
from datasets import load_dataset

# loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# convert to datetime
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
id_min_salary = df['salary_year_avg'].idxmin()

# %%
# df.iloc[id_min_salary]
df['job_country'].iloc[id_min_salary]
# Out:
# 'Brazil'

# %%
df[(df.job_country == 'Indonesia') & (df.job_title_short == 'Data Analyst')]
# Out:
#        job_title_short                                          job_title  \
# 3036      Data Analyst                      Retail Data Analyst-Indonesia
# 9167      Data Analyst                                       Data Analyst
# 16520     Data Analyst          Assistant Manager, Data Analyst Transport
# 23816     Data Analyst  Loker Pabrik Indofood Jakarta Pusat Lulusan S1...
# 29910     Data Analyst                        IT Analytics and Automation
# ...                ...                                                ...
# 784788    Data Analyst                                       Data Analyst
# 784893    Data Analyst                              Data Analyst - Middle
# 785194    Data Analyst                                       Data Analyst
# 785271    Data Analyst                                       Data Analyst
# 785567    Data Analyst                                Data Analyst Intern
#
#                                              job_location             job_via  \
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Lesotho                3
# Mauritania             3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
# df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].median()
# df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].median()
# df.groupby('job_title_short')['salary_year_avg'].median()
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
# df['job_country'].value_counts().head(20)
df['job_country'].isin(['Indonesia']).any()
# Out:
# np.True_

# %%
id_jobs = df[df['job_country'] == 'Indonesia']

# %%
id_jobs = id_jobs[id_jobs['salary_year_avg'].notna()]

# %%
id_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by='median', ascending=False)
# Out:
#                              median       min       max  count
# job_title_short
# Senior Data Engineer       147500.0  147500.0  147500.0      2
# Data Engineer              132910.5   72000.0  147500.0      6
# Software Engineer          123000.0  123000.0  123000.0      1
# Senior Data Scientist      118350.0   79200.0  157500.0      2
# Machine Learning Engineer  115400.0   64800.0  166000.0      2
# Senior Data Analyst        111175.0  109500.0  111175.0      3
# Data Scientist              90000.5   50400.0  157500.0      5
# Data Analyst                77017.5   50400.0  132500.0     13
# Business Analyst            64800.0   50400.0   64800.0      3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['median'].plot(kind='hist', bins=20, title='median')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
